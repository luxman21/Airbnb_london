# %%
import pandas as pd 
import numpy as np 
import matplotlib as plt 
import seaborn as sns

# configure pandas 
pd.options.display.max_columns = None
pd.options.display.float_format = '{:.2f}'.format

# %%
df = pd.read_csv('data/listings2.csv')

# %%
df.head()
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  13913  https://www.airbnb.com/rooms/13913  20211207182339   2021-12-09
# 1  15400  https://www.airbnb.com/rooms/15400  20211207182339   2021-12-09
# 2  17402  https://www.airbnb.com/rooms/17402  20211207182339   2021-12-09
# 3  17506  https://www.airbnb.com/rooms/17506  20211207182339   2021-12-09
# 4  25123  https://www.airbnb.com/rooms/25123  20211207182339   2021-12-09
#
#                                                 name  \
# 0                Holiday London DB Room Let-on going
# 1                Bright Chelsea  Apartment. Chelsea!
# 2              Superb 3-Bed/2 Bath & Wifi: Trendy W1
# 3  Boutique Chelsea/Fulham Double bed 5-star ensuite
# 4                  Clean big Room in London (Room 1)
#
#                                          description  \
# 0  My bright double bedroom with a large window h...
# 1  Lots of windows and light.  St Luke's Gardens ...
# ...

# %% [markdown]
# # Perform inital EDA

# %%
# produce initial report for the dataset 

print(
    f'Shape of the db:\n\n{df.shape}\n\n' 
    f'Number of missing values in the data set:\n\n{df.isna().sum()}\n\n'
    f'Check for unique id count:\n\n{df.id.nunique()}\n\n'
    f'Check for unique host id count:\n\n{df.host_id.nunique()}'
)
# Out:
# Shape of the db:
#
# (66641, 74)
#
# Number of missing values in the data set:
#
# id                                                  0
# listing_url                                         0
# scrape_id                                           0
# last_scraped                                        0
# name                                               24
#                                                 ...
# calculated_host_listings_count                      0
# calculated_host_listings_count_entire_homes         0
# calculated_host_listings_count_private_rooms        0
# calculated_host_listings_count_shared_rooms         0
# reviews_per_month                               18559
# Length: 74, dtype: int64
#
# Check for unique id count:
#
# 66641
#
# Check for unique host id count:
#
# 44695

# %%
df.host_id.value_counts()
# Out:
# 33889201     845
# 226804666    535
# 28820321     252
# 137094377    250
# 378060726    222
#             ...
# 121803582      1
# 13968497       1
# 13519855       1
# 124352218      1
# 4286437        1
# Name: host_id, Length: 44695, dtype: int64

# %%
df.query('host_id==33889201')[:5]
# Out:
#            id                           listing_url       scrape_id  \
# 5849  6654036  https://www.airbnb.com/rooms/6654036  20211207182339
# 5877  6683135  https://www.airbnb.com/rooms/6683135  20211207182339
# 5880  6684343  https://www.airbnb.com/rooms/6684343  20211207182339
# 7927  8206251  https://www.airbnb.com/rooms/8206251  20211207182339
# 8194  8449051  https://www.airbnb.com/rooms/8449051  20211207182339
#
#      last_scraped                                               name  \
# 5849   2021-12-09  Lovely 2BR, In the Heart of Westminster, by Veeve
# 5877   2021-12-09     Modern Thameside 2BR, Chelsea Bridge, by Veeve
# 5880   2021-12-08         3 BR with private garden, Putney, by Veeve
# 7927   2021-12-08          Up to 20% off! Open-plan 2 bed, Islington
# 8194   2021-12-08   Bright & spacious 4 BR, near the river, by Veeve
#
#                                             description  \
# 5849  Comfortable 2 bed, right in the heart of Londo...
# ...

# %%
df['last_scraped'] = pd.to_datetime(df['last_scraped'])
print(f'the max and min date in the df {df.last_scraped.max()} and min is {df.last_scraped.min()}')
# Out:
# the max and min date in the df 2021-12-14 00:00:00 and min is 2021-12-07 00:00:00

# %%
# conver the price to be numeric 

df['price'] = df['price'].str.replace('[\$\,]', '').astype(float)
# Out:
# /var/folders/kg/7wqk_2g57cv7kxzcl24c2_sc0000gn/T/ipykernel_21472/1277119490.py:3: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['price'] = df['price'].str.replace('[\$\,]', '').astype(float)

# %%
# the average price for a night in london 
print(df.price.mean())
# Out:
# 145.20722978346663
